# %%
# conda install -c conda-forge xarray dask netCDF4 bottleneck

# %%
# standard set of imports:

import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt
from IPython.display import display, Markdown, Latex
import seaborn as sns

# %matplotlib inline

# %%
data = np.random.rand(4, 3)

locs = ["IA", "IL", "IN"]
times = pd.date_range("2000-01-01", periods=4)
foo = xr.DataArray(data, coords=[times, locs], dims=["time", "space"])
foo
# Out:
# <xarray.DataArray (time: 4, space: 3)>
# array([[0.71825266, 0.57385416, 0.11398828],
#        [0.67625691, 0.53164749, 0.30657224],
#        [0.60437878, 0.52799091, 0.3200647 ],
#        [0.3443407 , 0.10814019, 0.95590348]])
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-01 2000-01-02 2000-01-03 2000-01-04
#   * space    (space) <U2 'IA' 'IL' 'IN'

# %%
temp = 15 + 8 * np.random.randn(2, 2, 3)

precip = 10 * np.random.rand(2, 2, 3)

lon = [[-99.83, -99.32], [-99.79, -99.23]]

lat = [[42.25, 42.21], [42.63, 42.59]]

ds = xr.Dataset(
{
   ....:         "temperature": (["x", "y", "time"], temp),
   ....:         "precipitation": (["x", "y", "time"], precip),
   ....:     },
   ....:     coords={
   ....:         "lon": (["x", "y"], lon),
   ....:         "lat": (["x", "y"], lat),
   ....:         "time": pd.date_range("2014-09-06", periods=3),
   ....:         "reference_time": pd.Timestamp("2014-09-05"),
   ....:     },
   ....: )
   ....: 

ds
# Out:
#   File "/var/folders/pv/75tqx38s3zxcjr22whprl6pc0000gn/T/ipykernel_3988/240046996.py", line 10
#     ....:     {
#         ^
# SyntaxError: invalid syntax
